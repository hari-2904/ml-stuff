# %%
import matplotlib as mpl
import pandas as pd
series = pd.read_csv('../input/daily-total-female-births.csv', header=0)
print(type(series))
print(series.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
series['Date'] = pd.to_datetime(series['Date'])
series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    365 non-null    datetime64[ns]
#  1   Births  365 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.8 KB

# %%
series[series['Date'].dt.month == 1]
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52
# 20 1959-01-21      34
# 21 1959-01-22      53
# 22 1959-01-23      39
# 23 1959-01-24      32
# 24 1959-01-25      37
# 25 1959-01-26      43
# 26 1959-01-27      39
# 27 1959-01-28      35
# 28 1959-01-29      44
# 29 1959-01-30      38
# 30 1959-01-31      24

# %%
series['Births'].describe()
# Out:
# count    365.000000
# mean      41.980822
# std        7.348257
# min       23.000000
# 25%       37.000000
# 50%       42.000000
# 75%       46.000000
# max       73.000000
# Name: Births, dtype: float64

# %%
temp = pd.read_csv('../input/daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True)
temp
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
temp.plot()
mpl.pyplot.show()

# %%
df = pd.DataFrame()
df['month'] = [temp.index[i].month for i in range(len(temp))]
df['day'] = [temp.index[i].day for i in range(len(temp))]
df['temp'] = [temp['Temp'][i] for i in range(len(temp))]
df
# Out:
# C:\Users\harir\AppData\Local\Temp\ipykernel_26440\1341426160.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['temp'] = [temp['Temp'][i] for i in range(len(temp))]
#       month  day  temp
# 0         1    1  20.7
# 1         1    2  17.9
# 2         1    3  18.8
# 3         1    4  14.6
# 4         1    5  15.8
# ...     ...  ...   ...
# 3645     12   27  14.0
# 3646     12   28  13.6
# 3647     12   29  13.5
# 3648     12   30  15.7
# 3649     12   31  13.0
#
# [3650 rows x 3 columns]

# %%
df = pd.read_excel('../input/titanic3.xls')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object
