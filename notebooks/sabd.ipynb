# %% [markdown]
# ***SABD Analysis***

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('../input/school/sabd.csv', index_col=0)
df.head()
# Out:
#    id_men    id_pers       id_depl  heuredep  mindep  heurearr  minarr  \
# 1  101012  101012001  1.010120e+09        14       0        14       5
# 2  101012  101012001  1.010120e+09        14      35        14      40
# 3  101012  101012001  1.010120e+09        14      45        15       5
# 4  101012  101012001  1.010120e+09        15      10        15      30
# 5  101012  101012001  1.010120e+09        20      45        21      10
#
#       D12  motifor  NB_velo  VP_DISPO  duree motifor1              deptime  \
# 1   290.0        1        1         0      5      DOM  2024-02-01 14:00:00
# 2   290.0       32        1         0      5      SHO  2024-02-01 14:35:00
# 3  1159.0        1        1         0     20      DOM  2024-02-01 14:45:00
# 4  1159.0       42        1         0     20      SHO  2024-02-01 15:10:00
# 5  1449.0        1        1         0     25      DOM  2024-02-01 20:45:00
#
#                arrtime              midtime  heuremid  nb_veh  cluster  rhour
# ...

# %%
df = df.iloc[:,[7,-3,-8,-1]]

# %%
df = df.values

# %%
X = df[:,0:4]
Y = df[:,-1]
